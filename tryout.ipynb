# %% [markdown]
# Goal: Given a vector of features detailing the health-related data of an individual, predict if the situation will lead to MICHD or not. This will involve applying binary classification.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

x_train = pd.read_csv('data/x_train.csv')

drop_cols = ['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE', 'SEQNO','_PSU']
x_train.drop(drop_cols, axis = 1, inplace = True)
x_train.head(20)


## NA value treatment


## normalize continuous and one-hot categorial

categorical_cols = []
continuous_cols = 


scaler = MinMaxScaler()
x_train[continuous_cols] = scaler.fit_transform(df[continuous_cols])
x_train = pd.get_dummies(x_train, columns=categorical_cols)
# Out:
#     Id  CTELENUM  PVTRESD1  COLGHOUS  STATERES  CELLFON3  LADULT  NUMADULT  \
# 0    0       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# 1    1       1.0       1.0       NaN       1.0       1.0     NaN       2.0
# 2    2       1.0       1.0       NaN       1.0       2.0     NaN       2.0
# 3    3       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# 4    4       1.0       1.0       NaN       1.0       1.0     NaN       1.0
# 5    5       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# 6    6       1.0       1.0       NaN       1.0       1.0     NaN       1.0
# 7    7       1.0       1.0       NaN       1.0       1.0     NaN       1.0
# 8    8       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# 9    9       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# 10  10       NaN       NaN       NaN       NaN       NaN     NaN       NaN
# ...
