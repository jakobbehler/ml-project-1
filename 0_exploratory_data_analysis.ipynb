# %% [markdown]
# ### 1. Data overview
#
# - Inspect feature types (categorical, continuous, ordinal, binary)
# - Check target distribution (class balance)
#
# ### 2. Data quality
#
# - Missing values (counts & % per column) --> how will we impute them? Drop, Mean or regressioN????
# - Invalid values (e.g., negatives where impossible, out-of-range categories)
#
# ### 3. Target variable
#
# - Class balance (is it imbalanced? → may need resampling/weights) (how many are 1 how many -1)
# - Compare descriptive stats of features by target class (distributions of features dependent on the category -1 1)
#
# ### 4. Feature distributions
#
# - Histograms / density plots for continuous features
# - Boxplots per class to spot differences & outliers
# - Bar plots for categorical/discrete features
#
# ### 5. Relationships among features
#
# - correlation tables
#
# ### 6. Data Preparation
#
# - Encode categorical features (one-hot, ordinal, or embeddings)
# - Scaling / Z-score of continuous
# - Decide how to handle missing data (imputation/drop)
# - Consider feature transformations (log, binning, etc.)

# %%
import numpy as np
import os

from helper_functions.A_loading_helpers import load_numpy
x_tr_clean_interim = load_numpy('data/interim/x_train_processed_with_nan.npy')
# Out:
# Loaded NumPy array from: /Users/jakobbehler/Documents/2_EPFL/23_Content/MA3/machine-learning/ml-project-1/data/interim/x_train_processed_with_nan.npy | shape: (328135, 945)
